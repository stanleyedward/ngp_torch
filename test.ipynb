# %%
import matplotlib.pyplot as plt
from testing import NSVFDataset

# %%
val_data = NSVFDataset("Synthetic_NSVF/Bike", "val")
train_data = NSVFDataset("Synthetic_NSVF/Bike", "train")
# Out:
# Loading 100 val images ...
# 0it [00:00, ?it/s]
# 100it [00:03, 29.11it/s]
# Loading 100 train images ...
# 100it [00:03, 31.43it/s]

# %%
len(train_data)
# Out:
# 8192000

# %%
plt.imshow(val_data[21]['rgb'].reshape(800,800,3))

# %%
dataset_val[0]['rgb'].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataset_val[0]['rgb'].shape
#
# NameError: name 'dataset_val' is not defined

# %%
# Out:
# {'rays': tensor([-0.0000,  0.0000,  2.3810,  0.1696, -0.2470, -0.9541]),
#  'rgb': tensor([0., 0., 0.]),
#  'idx': 138644}

# %%
dataset[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 dataset[3]
#
# File ~/Documents/shid/ngp_torch/dataset.py:90, in NSVFDataset.__getitem__(self, index)
#      83     sample = {
#      84         'rays': self.rays[index, :6],
#      85         'rgb': self.rays[index, 6:9],
#      86         'idx': index
#      87         }
#      88 else:
#      89     sample = {
# ---> 90         'rays': self.rays[index][:, :6],
#      91         'rgb': self.rays[index][:, 6:9]
#      92              }
#      93 return sample
#
# KeyError: 3
